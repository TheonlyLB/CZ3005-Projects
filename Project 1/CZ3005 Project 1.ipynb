# %% [markdown]
# # CZ3005 Project 1 - Balancing a Pole on a Cart

# %% [markdown]
# ### Done by: Zon Liew (U1921098F), Charlotte Teo (U2022021G), Paul Low (U2022421F)

# %% [markdown]
# Objectives:
# Apply Linear annealed policy with the EpsGreedyQPolicy as the inner policy:
# Achieve a DQN model that trains in the least possible number of episodes.
# Balance pole on the cart for 500 steps for 100 consecutive episodes while testing.
#
# Epsilon-Greedy chooses the optimal action at each step, but sometimes randomly chooses an unlikely option.
# We specify an initially high exploration rate (epsilon) of 1 at the beginning of Q function training because we know nothing about the importance of the Q table. Epsilon value is decreased as the agent has more confidence in the Q values.
#
# A DQN agent can be used in any environment which has a discrete action space.
# It is based on the Q - Network, a neural network model that can learn to predict Q-Values (expected returns) for all actions, given an observation from the environment.
#
# The hyperparameters are:
#
# Size of 1st fully connected layer: 256
# Size of 2nd fully connected layer: 512
# Period of the update of the target network parameters: 1000 steps
# Discount factor: 0.99
# Decay factor for epsilon in epsilon-greedy policy: 0.99
# Minimum epsilon in epsilon-greeddy policy: 1E-4
# Learning rate: 3E-4
# Size of replay memory: 1000000
# Period of experience replay: 4 steps
# PER alpha: 0.2
# PER beta0: 0.4

# %% [markdown]
# ## Task 1

# %%
#Install keras rl2 which seamlessly integrates with the  OpenAI Gym  to evaluate and play around with DQN Algorithm
# !pip install keras-rl2
# !pip install dopamine-rl
#Install Open AI Gym for the Cart Pole Environment
# !pip install gym

# !pip install tensorflow --upgrade
# !pip install rl-agents==0.1.1

# %%
import gym
import matplotlib.pyplot as plt
import keras
from keras import Sequential
from keras.layers import Input, Flatten, Dense
import numpy as np
import rl
from rl.memory import SequentialMemory
from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy

from tensorflow.keras.optimizers import Adam

# %%
#Load the CartPole environment from the OpenAI Gym suite
env = gym.make("CartPole-v1")

# %%
initial_observation = env.reset()
print("Initial observation:", initial_observation)
cumulative_reward = 0
done = False
# Out:
# Initial observation: [-0.024546    0.028255   -0.03943262 -0.00854617]

# %%
#Building DQN Agent with Keras-RL
# setup experience replay buffer
memory = SequentialMemory(limit=50000, window_length=1)

# setup the Linear annealed policy with the EpsGreedyQPolicy as the inner policy
policy =  LinearAnnealedPolicy(inner_policy=  EpsGreedyQPolicy(),   # policy used to select actions
                               attr='eps',                          # attribute in the inner policy to vary             
                               value_max=1.0,                       # maximum value of attribute that is varying
                               value_min=0.1,                       # minimum value of attribute that is varying
                               value_test=0.05,                     # test if the value selected is < 0.05
                               nb_steps=10000)                      # the number of steps between value_max and value_min

#Feed-Forward Neural Network Model for Deep Q Learning (DQN)
model = Sequential()
#print(env.observation_space)
#Input is 1 observation vector, and the number of observations in that vector 
model.add(Input(shape=(1,env.observation_space.shape[0])))
model.add(Flatten())
#Hidden layers with 24 nodes each
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
#Output is the number of actions in the action space
model.add(Dense(env.action_space.n, activation='linear')) 


#Feed-Forward Neural Network Architecture Summary
print(model.summary())

#Defining DQN Agent for DQN Model
dqn = DQNAgent(model=model,                     # Q-Network model
               nb_actions=env.action_space.n,   # number of actions
               memory=memory,                   # experience replay memory
               nb_steps_warmup=25,              # how many steps are waited before starting experience replay
               target_model_update=1e-2,        # how often the target network is updated
               policy=policy,                   # the action selection policy
              enable_dueling_network=True)                   

# Configure and compile agent. 
#Use built-in tensorflow.keras Adam optimizer and evaluation metrics            
#Adam._name = 'Adam'
dqn.compile(keras.optimizers.Adam(learning_rate=2.5e-4,epsilon = 0.01), metrics = ["mse",'accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 4)                 0
#
#  dense (Dense)               (None, 256)               1280
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 34,434
# Trainable params: 34,434
# Non-trainable params: 0
# _________________________________________________________________
# None
# Metal device set to: Apple M2
# WARNING:tensorflow:From /Applications/miniconda3/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-03-05 12:29:04.556395: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-05 12:29:04.556420: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-03-05 12:29:04.561171: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-03-05 12:29:04.562759: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-05 12:29:04.563181: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:04.572637: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_3_1/bias/Assign' id:185 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_1/bias, dense_3_1/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-05 12:29:04.575235: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:04.594391: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:04.606613: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
#Finally fit and train the agent
history = dqn.fit(env, nb_steps=5000, visualize=False, verbose=10)
#dqn.save_weights('dqn_weights.h5f', overwrite=True)
#dqn.load_weights('dqn_weights.h5f')
# Out:
# Training for 5000 steps ...
#     9/5000: episode: 1, duration: 0.177s, episode steps:   9, steps per second:  51, episode reward:  9.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.000 [0.000, 0.000],  loss: --, mse: --, accuracy: --, mean_q: --, mean_eps: --
# /Applications/miniconda3/lib/python3.10/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-03-05 12:29:08.088827: W tensorflow/c/c_api.cc:291] Operation '{name:'lambda/sub' id:116 op device:{requested: '', assigned: ''} def:{{{node lambda/sub}} = Sub[T=DT_FLOAT, _has_manual_control_dependencies=true](lambda/add, lambda/Mean)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-05 12:29:08.096543: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.105102: W tensorflow/c/c_api.cc:291] Operation '{name:'count_1/Assign' id:354 op device:{requested: '', assigned: ''} def:{{{node count_1/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](count_1, count_1/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-05 12:29:08.112113: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.123383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#    23/5000: episode: 2, duration: 0.030s, episode steps:  14, steps per second: 471, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.429 [0.000, 1.000],  loss: --, mse: --, accuracy: --, mean_q: --, mean_eps: --
# /Applications/miniconda3/lib/python3.10/site-packages/keras_rl2-1.0.5-py3.10.egg/rl/memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# /Applications/miniconda3/lib/python3.10/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-03-05 12:29:08.293248: W tensorflow/c/c_api.cc:291] Operation '{name:'lambda_1/sub' id:208 op device:{requested: '', assigned: ''} def:{{{node lambda_1/sub}} = Sub[T=DT_FLOAT, _has_manual_control_dependencies=true](lambda_1/add, lambda_1/Mean)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-05 12:29:08.298719: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.455527: W tensorflow/c/c_api.cc:291] Operation '{name:'loss_3/AddN' id:498 op device:{requested: '', assigned: ''} def:{{{node loss_3/AddN}} = AddN[N=2, T=DT_FLOAT, _has_manual_control_dependencies=true](loss_3/mul, loss_3/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-05 12:29:08.465062: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.473348: W tensorflow/c/c_api.cc:291] Operation '{name:'training/Adam/dense_3/bias/m/Assign' id:737 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_3/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_3/bias/m, training/Adam/dense_3/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-03-05 12:29:08.482054: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.496146: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.796793: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.812230: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.827544: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.842480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-05 12:29:08.857287: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#    65/5000: episode: 3, duration: 1.210s, episode steps:  42, steps per second:  35, episode reward: 42.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.476 [0.000, 1.000],  loss: 0.495919, mse: 0.507855, accuracy: 0.431891, mean_q: 0.130067, mean_eps: 0.995950
#    79/5000: episode: 4, duration: 0.241s, episode steps:  14, steps per second:  58, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.643 [0.000, 1.000],  loss: 0.401616, mse: 0.429986, accuracy: 0.444196, mean_q: 0.204391, mean_eps: 0.993565
#   104/5000: episode: 5, duration: 0.413s, episode steps:  25, steps per second:  61, episode reward: 25.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.400 [0.000, 1.000],  loss: 0.378018, mse: 0.427811, accuracy: 0.451250, mean_q: 0.271155, mean_eps: 0.991810
#   126/5000: episode: 6, duration: 0.365s, episode steps:  22, steps per second:  60, episode reward: 22.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.636 [0.000, 1.000],  loss: 0.333697, mse: 0.424853, accuracy: 0.470170, mean_q: 0.378474, mean_eps: 0.989695
#   157/5000: episode: 7, duration: 0.493s, episode steps:  31, steps per second:  63, episode reward: 31.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.516 [0.000, 1.000],  loss: 0.300792, mse: 0.450612, accuracy: 0.439516, mean_q: 0.487271, mean_eps: 0.987310
#   178/5000: episode: 8, duration: 0.336s, episode steps:  21, steps per second:  62, episode reward: 21.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.333 [0.000, 1.000],  loss: 0.262090, mse: 0.484940, accuracy: 0.502976, mean_q: 0.604655, mean_eps: 0.984970
#   209/5000: episode: 9, duration: 0.488s, episode steps:  31, steps per second:  63, episode reward: 31.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.581 [0.000, 1.000],  loss: 0.241180, mse: 0.563373, accuracy: 0.487903, mean_q: 0.736315, mean_eps: 0.982630
#   224/5000: episode: 10, duration: 0.248s, episode steps:  15, steps per second:  61, episode reward: 15.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.667 [0.000, 1.000],  loss: 0.211644, mse: 0.632695, accuracy: 0.533333, mean_q: 0.860945, mean_eps: 0.980560
#   238/5000: episode: 11, duration: 0.227s, episode steps:  14, steps per second:  62, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.786 [0.000, 1.000],  loss: 0.195144, mse: 0.688938, accuracy: 0.513393, mean_q: 0.939572, mean_eps: 0.979255
#   257/5000: episode: 12, duration: 0.302s, episode steps:  19, steps per second:  63, episode reward: 19.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.632 [0.000, 1.000],  loss: 0.182264, mse: 0.788063, accuracy: 0.490132, mean_q: 1.043423, mean_eps: 0.977770
#   288/5000: episode: 13, duration: 0.496s, episode steps:  31, steps per second:  63, episode reward: 31.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.387 [0.000, 1.000],  loss: 0.154924, mse: 1.049590, accuracy: 0.523185, mean_q: 1.271032, mean_eps: 0.975520
#   300/5000: episode: 14, duration: 0.201s, episode steps:  12, steps per second:  60, episode reward: 12.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.583 [0.000, 1.000],  loss: 0.157028, mse: 1.253160, accuracy: 0.575521, mean_q: 1.423881, mean_eps: 0.973585
#   338/5000: episode: 15, duration: 0.600s, episode steps:  38, steps per second:  63, episode reward: 38.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.579 [0.000, 1.000],  loss: 0.171984, mse: 1.541903, accuracy: 0.515625, mean_q: 1.615291, mean_eps: 0.971335
#   352/5000: episode: 16, duration: 0.254s, episode steps:  14, steps per second:  55, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.357 [0.000, 1.000],  loss: 0.188455, mse: 1.803040, accuracy: 0.549107, mean_q: 1.780854, mean_eps: 0.968995
#   425/5000: episode: 17, duration: 1.141s, episode steps:  73, steps per second:  64, episode reward: 73.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.575 [0.000, 1.000],  loss: 0.178283, mse: 2.342868, accuracy: 0.518408, mean_q: 2.090154, mean_eps: 0.965080
#   441/5000: episode: 18, duration: 0.258s, episode steps:  16, steps per second:  62, episode reward: 16.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.688 [0.000, 1.000],  loss: 0.142108, mse: 2.997902, accuracy: 0.576172, mean_q: 2.435483, mean_eps: 0.961075
#   455/5000: episode: 19, duration: 0.234s, episode steps:  14, steps per second:  60, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 0.149723, mse: 3.325782, accuracy: 0.506696, mean_q: 2.573382, mean_eps: 0.959725
#   466/5000: episode: 20, duration: 0.188s, episode steps:  11, steps per second:  58, episode reward: 11.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.273 [0.000, 1.000],  loss: 0.207668, mse: 3.882539, accuracy: 0.542614, mean_q: 2.785467, mean_eps: 0.958600
#   484/5000: episode: 21, duration: 0.296s, episode steps:  18, steps per second:  61, episode reward: 18.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.389 [0.000, 1.000],  loss: 0.245095, mse: 4.187412, accuracy: 0.560764, mean_q: 2.896067, mean_eps: 0.957295
#   511/5000: episode: 22, duration: 0.432s, episode steps:  27, steps per second:  63, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.667 [0.000, 1.000],  loss: 0.205085, mse: 4.572106, accuracy: 0.533565, mean_q: 3.039951, mean_eps: 0.955270
#   524/5000: episode: 23, duration: 0.215s, episode steps:  13, steps per second:  61, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.231 [0.000, 1.000],  loss: 0.281310, mse: 5.018741, accuracy: 0.507212, mean_q: 3.143802, mean_eps: 0.953470
#   547/5000: episode: 24, duration: 0.368s, episode steps:  23, steps per second:  62, episode reward: 23.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.391 [0.000, 1.000],  loss: 0.303279, mse: 5.518780, accuracy: 0.512228, mean_q: 3.302413, mean_eps: 0.951850
#   574/5000: episode: 25, duration: 0.426s, episode steps:  27, steps per second:  63, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.481 [0.000, 1.000],  loss: 0.310904, mse: 6.043216, accuracy: 0.533565, mean_q: 3.462613, mean_eps: 0.949600
#   593/5000: episode: 26, duration: 0.310s, episode steps:  19, steps per second:  61, episode reward: 19.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.632 [0.000, 1.000],  loss: 0.281233, mse: 6.581147, accuracy: 0.557566, mean_q: 3.630670, mean_eps: 0.947530
#   615/5000: episode: 27, duration: 0.365s, episode steps:  22, steps per second:  60, episode reward: 22.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.545 [0.000, 1.000],  loss: 0.304791, mse: 7.315938, accuracy: 0.531250, mean_q: 3.814903, mean_eps: 0.945685
#   628/5000: episode: 28, duration: 0.220s, episode steps:  13, steps per second:  59, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.538 [0.000, 1.000],  loss: 0.393667, mse: 8.032506, accuracy: 0.555288, mean_q: 3.975828, mean_eps: 0.944110
#   652/5000: episode: 29, duration: 0.394s, episode steps:  24, steps per second:  61, episode reward: 24.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.542 [0.000, 1.000],  loss: 0.336694, mse: 8.094347, accuracy: 0.541667, mean_q: 4.007053, mean_eps: 0.942445
#   685/5000: episode: 30, duration: 0.540s, episode steps:  33, steps per second:  61, episode reward: 33.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.455 [0.000, 1.000],  loss: 0.441814, mse: 9.125517, accuracy: 0.523674, mean_q: 4.233840, mean_eps: 0.939880
#   716/5000: episode: 31, duration: 0.495s, episode steps:  31, steps per second:  63, episode reward: 31.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.484 [0.000, 1.000],  loss: 0.370458, mse: 10.186131, accuracy: 0.470766, mean_q: 4.492747, mean_eps: 0.937000
#   737/5000: episode: 32, duration: 0.336s, episode steps:  21, steps per second:  62, episode reward: 21.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.476 [0.000, 1.000],  loss: 0.324675, mse: 11.045902, accuracy: 0.526786, mean_q: 4.691716, mean_eps: 0.934660
#   754/5000: episode: 33, duration: 0.275s, episode steps:  17, steps per second:  62, episode reward: 17.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.412 [0.000, 1.000],  loss: 0.372855, mse: 11.655897, accuracy: 0.487132, mean_q: 4.804287, mean_eps: 0.932950
#   772/5000: episode: 34, duration: 0.289s, episode steps:  18, steps per second:  62, episode reward: 18.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.333 [0.000, 1.000],  loss: 0.468803, mse: 12.419927, accuracy: 0.472222, mean_q: 4.946034, mean_eps: 0.931375
#   802/5000: episode: 35, duration: 0.480s, episode steps:  30, steps per second:  63, episode reward: 30.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.567 [0.000, 1.000],  loss: 0.376494, mse: 13.334414, accuracy: 0.507292, mean_q: 5.154551, mean_eps: 0.929215
#   829/5000: episode: 36, duration: 0.429s, episode steps:  27, steps per second:  63, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.519 [0.000, 1.000],  loss: 0.452360, mse: 13.911018, accuracy: 0.467593, mean_q: 5.232128, mean_eps: 0.926650
#   859/5000: episode: 37, duration: 0.474s, episode steps:  30, steps per second:  63, episode reward: 30.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.400 [0.000, 1.000],  loss: 0.537451, mse: 15.552714, accuracy: 0.487500, mean_q: 5.509628, mean_eps: 0.924085
#   889/5000: episode: 38, duration: 0.475s, episode steps:  30, steps per second:  63, episode reward: 30.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 0.473308, mse: 16.371526, accuracy: 0.494792, mean_q: 5.667244, mean_eps: 0.921385
#   905/5000: episode: 39, duration: 0.257s, episode steps:  16, steps per second:  62, episode reward: 16.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.312 [0.000, 1.000],  loss: 0.427665, mse: 17.211866, accuracy: 0.480469, mean_q: 5.847983, mean_eps: 0.919315
#   935/5000: episode: 40, duration: 0.476s, episode steps:  30, steps per second:  63, episode reward: 30.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 0.586788, mse: 18.375977, accuracy: 0.481250, mean_q: 6.001752, mean_eps: 0.917245
#   952/5000: episode: 41, duration: 0.275s, episode steps:  17, steps per second:  62, episode reward: 17.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.353 [0.000, 1.000],  loss: 0.450112, mse: 18.783178, accuracy: 0.485294, mean_q: 6.107788, mean_eps: 0.915130
#  1000/5000: episode: 42, duration: 0.809s, episode steps:  48, steps per second:  59, episode reward: 48.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.458 [0.000, 1.000],  loss: 0.610038, mse: 20.493047, accuracy: 0.472656, mean_q: 6.357744, mean_eps: 0.912205
#  1027/5000: episode: 43, duration: 0.491s, episode steps:  27, steps per second:  55, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.556 [0.000, 1.000],  loss: 0.421490, mse: 22.613844, accuracy: 0.525463, mean_q: 6.733652, mean_eps: 0.908830
#  1063/5000: episode: 44, duration: 0.588s, episode steps:  36, steps per second:  61, episode reward: 36.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.472 [0.000, 1.000],  loss: 0.543036, mse: 23.858102, accuracy: 0.500000, mean_q: 6.914747, mean_eps: 0.905995
#  1083/5000: episode: 45, duration: 0.339s, episode steps:  20, steps per second:  59, episode reward: 20.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.650 [0.000, 1.000],  loss: 0.604626, mse: 24.735685, accuracy: 0.521875, mean_q: 7.062737, mean_eps: 0.903475
#  1096/5000: episode: 46, duration: 0.218s, episode steps:  13, steps per second:  60, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.385 [0.000, 1.000],  loss: 0.925829, mse: 25.397874, accuracy: 0.512019, mean_q: 7.093401, mean_eps: 0.901990
#  1129/5000: episode: 47, duration: 0.533s, episode steps:  33, steps per second:  62, episode reward: 33.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.485 [0.000, 1.000],  loss: 0.582609, mse: 27.203467, accuracy: 0.528409, mean_q: 7.388348, mean_eps: 0.899920
#  1167/5000: episode: 48, duration: 0.616s, episode steps:  38, steps per second:  62, episode reward: 38.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.553 [0.000, 1.000],  loss: 0.539674, mse: 28.953198, accuracy: 0.495066, mean_q: 7.643722, mean_eps: 0.896725
#  1191/5000: episode: 49, duration: 0.404s, episode steps:  24, steps per second:  59, episode reward: 24.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.542 [0.000, 1.000],  loss: 0.953418, mse: 30.519126, accuracy: 0.535156, mean_q: 7.843724, mean_eps: 0.893935
#  1268/5000: episode: 50, duration: 1.235s, episode steps:  77, steps per second:  62, episode reward: 77.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.506 [0.000, 1.000],  loss: 0.873447, mse: 33.421096, accuracy: 0.530844, mean_q: 8.227739, mean_eps: 0.889390
#  1282/5000: episode: 51, duration: 0.234s, episode steps:  14, steps per second:  60, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.643 [0.000, 1.000],  loss: 0.607968, mse: 37.326115, accuracy: 0.513393, mean_q: 8.693133, mean_eps: 0.885295
#  1292/5000: episode: 52, duration: 0.172s, episode steps:  10, steps per second:  58, episode reward: 10.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.200 [0.000, 1.000],  loss: 0.618335, mse: 37.702396, accuracy: 0.506250, mean_q: 8.757565, mean_eps: 0.884215
#  1305/5000: episode: 53, duration: 0.220s, episode steps:  13, steps per second:  59, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.615 [0.000, 1.000],  loss: 0.925042, mse: 37.309361, accuracy: 0.466346, mean_q: 8.681611, mean_eps: 0.883180
#  1326/5000: episode: 54, duration: 0.341s, episode steps:  21, steps per second:  62, episode reward: 21.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.429 [0.000, 1.000],  loss: 0.598384, mse: 39.590220, accuracy: 0.492560, mean_q: 9.000659, mean_eps: 0.881650
#  1347/5000: episode: 55, duration: 0.339s, episode steps:  21, steps per second:  62, episode reward: 21.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.429 [0.000, 1.000],  loss: 0.818745, mse: 41.396327, accuracy: 0.476190, mean_q: 9.175813, mean_eps: 0.879760
#  1360/5000: episode: 56, duration: 0.217s, episode steps:  13, steps per second:  60, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.231 [0.000, 1.000],  loss: 0.548117, mse: 41.125443, accuracy: 0.507212, mean_q: 9.184869, mean_eps: 0.878230
#  1370/5000: episode: 57, duration: 0.179s, episode steps:  10, steps per second:  56, episode reward: 10.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.300 [0.000, 1.000],  loss: 0.726719, mse: 43.927588, accuracy: 0.546875, mean_q: 9.492569, mean_eps: 0.877195
#  1385/5000: episode: 58, duration: 0.258s, episode steps:  15, steps per second:  58, episode reward: 15.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.400 [0.000, 1.000],  loss: 0.759072, mse: 44.185045, accuracy: 0.472917, mean_q: 9.508198, mean_eps: 0.876070
#  1404/5000: episode: 59, duration: 0.320s, episode steps:  19, steps per second:  59, episode reward: 19.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.526 [0.000, 1.000],  loss: 1.305164, mse: 45.144376, accuracy: 0.504934, mean_q: 9.562980, mean_eps: 0.874540
#  1453/5000: episode: 60, duration: 0.794s, episode steps:  49, steps per second:  62, episode reward: 49.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.531 [0.000, 1.000],  loss: 1.144402, mse: 46.816886, accuracy: 0.507653, mean_q: 9.761275, mean_eps: 0.871480
#  1480/5000: episode: 61, duration: 0.440s, episode steps:  27, steps per second:  61, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.444 [0.000, 1.000],  loss: 1.192423, mse: 48.885166, accuracy: 0.555556, mean_q: 10.028386, mean_eps: 0.868060
#  1563/5000: episode: 62, duration: 1.310s, episode steps:  83, steps per second:  63, episode reward: 83.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.518 [0.000, 1.000],  loss: 1.286734, mse: 53.394976, accuracy: 0.511295, mean_q: 10.462091, mean_eps: 0.863110
#  1583/5000: episode: 63, duration: 0.326s, episode steps:  20, steps per second:  61, episode reward: 20.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.550 [0.000, 1.000],  loss: 0.818983, mse: 58.789297, accuracy: 0.525000, mean_q: 11.009526, mean_eps: 0.858475
#  1622/5000: episode: 64, duration: 0.615s, episode steps:  39, steps per second:  63, episode reward: 39.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.462 [0.000, 1.000],  loss: 1.296874, mse: 60.701327, accuracy: 0.538462, mean_q: 11.190634, mean_eps: 0.855820
#  1635/5000: episode: 65, duration: 0.224s, episode steps:  13, steps per second:  58, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.692 [0.000, 1.000],  loss: 1.126056, mse: 61.209392, accuracy: 0.521635, mean_q: 11.258954, mean_eps: 0.853480
#  1663/5000: episode: 66, duration: 0.447s, episode steps:  28, steps per second:  63, episode reward: 28.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 1.517186, mse: 63.504407, accuracy: 0.547991, mean_q: 11.429962, mean_eps: 0.851635
#  1706/5000: episode: 67, duration: 0.675s, episode steps:  43, steps per second:  64, episode reward: 43.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.535 [0.000, 1.000],  loss: 1.123313, mse: 66.809379, accuracy: 0.535610, mean_q: 11.762786, mean_eps: 0.848440
#  1738/5000: episode: 68, duration: 0.501s, episode steps:  32, steps per second:  64, episode reward: 32.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.531 [0.000, 1.000],  loss: 1.610650, mse: 70.035961, accuracy: 0.553711, mean_q: 12.054741, mean_eps: 0.845065
#  1753/5000: episode: 69, duration: 0.247s, episode steps:  15, steps per second:  61, episode reward: 15.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.467 [0.000, 1.000],  loss: 1.199415, mse: 70.598936, accuracy: 0.558333, mean_q: 12.136046, mean_eps: 0.842950
#  1793/5000: episode: 70, duration: 0.637s, episode steps:  40, steps per second:  63, episode reward: 40.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.525 [0.000, 1.000],  loss: 1.877197, mse: 75.217225, accuracy: 0.530469, mean_q: 12.439288, mean_eps: 0.840475
#  1808/5000: episode: 71, duration: 0.245s, episode steps:  15, steps per second:  61, episode reward: 15.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.400 [0.000, 1.000],  loss: 1.424148, mse: 76.542864, accuracy: 0.533333, mean_q: 12.555237, mean_eps: 0.838000
#  1882/5000: episode: 72, duration: 1.170s, episode steps:  74, steps per second:  63, episode reward: 74.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.541 [0.000, 1.000],  loss: 1.478457, mse: 81.436049, accuracy: 0.540963, mean_q: 12.987354, mean_eps: 0.833995
#  1928/5000: episode: 73, duration: 1.027s, episode steps:  46, steps per second:  45, episode reward: 46.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.522 [0.000, 1.000],  loss: 1.738187, mse: 87.283322, accuracy: 0.542799, mean_q: 13.424798, mean_eps: 0.828595
#  1952/5000: episode: 74, duration: 0.395s, episode steps:  24, steps per second:  61, episode reward: 24.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.625 [0.000, 1.000],  loss: 1.433430, mse: 90.646410, accuracy: 0.539062, mean_q: 13.697857, mean_eps: 0.825445
#  2058/5000: episode: 75, duration: 1.627s, episode steps: 106, steps per second:  65, episode reward: 106.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.509 [0.000, 1.000],  loss: 1.940650, mse: 96.118145, accuracy: 0.543337, mean_q: 14.067661, mean_eps: 0.819595
#  2071/5000: episode: 76, duration: 0.212s, episode steps:  13, steps per second:  61, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.692 [0.000, 1.000],  loss: 2.234407, mse: 103.355694, accuracy: 0.519231, mean_q: 14.524641, mean_eps: 0.814240
#  2187/5000: episode: 77, duration: 1.784s, episode steps: 116, steps per second:  65, episode reward: 116.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.509 [0.000, 1.000],  loss: 2.122865, mse: 107.995690, accuracy: 0.554149, mean_q: 14.913158, mean_eps: 0.808435
#  2218/5000: episode: 78, duration: 0.489s, episode steps:  31, steps per second:  63, episode reward: 31.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.548 [0.000, 1.000],  loss: 2.244726, mse: 114.469683, accuracy: 0.540323, mean_q: 15.386343, mean_eps: 0.801820
#  2286/5000: episode: 79, duration: 1.069s, episode steps:  68, steps per second:  64, episode reward: 68.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.471 [0.000, 1.000],  loss: 1.730354, mse: 121.847970, accuracy: 0.555607, mean_q: 15.928626, mean_eps: 0.797365
#  2318/5000: episode: 80, duration: 0.516s, episode steps:  32, steps per second:  62, episode reward: 32.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.438 [0.000, 1.000],  loss: 1.659329, mse: 127.421127, accuracy: 0.555664, mean_q: 16.314380, mean_eps: 0.792865
#  2331/5000: episode: 81, duration: 0.216s, episode steps:  13, steps per second:  60, episode reward: 13.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.615 [0.000, 1.000],  loss: 2.090836, mse: 130.945054, accuracy: 0.531250, mean_q: 16.469634, mean_eps: 0.790840
#  2357/5000: episode: 82, duration: 0.415s, episode steps:  26, steps per second:  63, episode reward: 26.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.538 [0.000, 1.000],  loss: 2.225897, mse: 131.929163, accuracy: 0.530048, mean_q: 16.501350, mean_eps: 0.789085
#  2371/5000: episode: 83, duration: 0.228s, episode steps:  14, steps per second:  61, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.643 [0.000, 1.000],  loss: 1.136682, mse: 139.393214, accuracy: 0.555804, mean_q: 16.992055, mean_eps: 0.787285
#  2420/5000: episode: 84, duration: 0.764s, episode steps:  49, steps per second:  64, episode reward: 49.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.490 [0.000, 1.000],  loss: 2.007575, mse: 139.151043, accuracy: 0.565051, mean_q: 16.976726, mean_eps: 0.784450
#  2454/5000: episode: 85, duration: 0.542s, episode steps:  34, steps per second:  63, episode reward: 34.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.471 [0.000, 1.000],  loss: 2.237156, mse: 146.830802, accuracy: 0.533088, mean_q: 17.380451, mean_eps: 0.780715
#  2473/5000: episode: 86, duration: 0.317s, episode steps:  19, steps per second:  60, episode reward: 19.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.526 [0.000, 1.000],  loss: 2.385773, mse: 145.025770, accuracy: 0.572368, mean_q: 17.336000, mean_eps: 0.778330
#  2521/5000: episode: 87, duration: 0.794s, episode steps:  48, steps per second:  60, episode reward: 48.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.521 [0.000, 1.000],  loss: 3.104228, mse: 147.719216, accuracy: 0.552083, mean_q: 17.445108, mean_eps: 0.775315
#  2561/5000: episode: 88, duration: 0.761s, episode steps:  40, steps per second:  53, episode reward: 40.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.475 [0.000, 1.000],  loss: 2.329993, mse: 154.620168, accuracy: 0.557813, mean_q: 17.914442, mean_eps: 0.771355
#  2621/5000: episode: 89, duration: 1.015s, episode steps:  60, steps per second:  59, episode reward: 60.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 2.601289, mse: 161.089005, accuracy: 0.569792, mean_q: 18.306183, mean_eps: 0.766855
#  2645/5000: episode: 90, duration: 0.383s, episode steps:  24, steps per second:  63, episode reward: 24.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.458 [0.000, 1.000],  loss: 1.607304, mse: 167.629955, accuracy: 0.565104, mean_q: 18.759629, mean_eps: 0.763075
#  2664/5000: episode: 91, duration: 0.307s, episode steps:  19, steps per second:  62, episode reward: 19.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.579 [0.000, 1.000],  loss: 2.409353, mse: 169.572295, accuracy: 0.549342, mean_q: 18.771608, mean_eps: 0.761140
#  2705/5000: episode: 92, duration: 0.638s, episode steps:  41, steps per second:  64, episode reward: 41.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.439 [0.000, 1.000],  loss: 2.338140, mse: 174.455468, accuracy: 0.544970, mean_q: 19.030323, mean_eps: 0.758440
#  2726/5000: episode: 93, duration: 0.340s, episode steps:  21, steps per second:  62, episode reward: 21.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.429 [0.000, 1.000],  loss: 2.786623, mse: 180.408826, accuracy: 0.550595, mean_q: 19.334042, mean_eps: 0.755650
#  2743/5000: episode: 94, duration: 0.282s, episode steps:  17, steps per second:  60, episode reward: 17.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.353 [0.000, 1.000],  loss: 3.092832, mse: 183.642148, accuracy: 0.500000, mean_q: 19.434097, mean_eps: 0.753940
#  2759/5000: episode: 95, duration: 0.263s, episode steps:  16, steps per second:  61, episode reward: 16.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.688 [0.000, 1.000],  loss: 2.252308, mse: 179.932795, accuracy: 0.544922, mean_q: 19.348245, mean_eps: 0.752455
#  2844/5000: episode: 96, duration: 1.372s, episode steps:  85, steps per second:  62, episode reward: 85.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.482 [0.000, 1.000],  loss: 2.370733, mse: 192.668773, accuracy: 0.548162, mean_q: 19.989492, mean_eps: 0.747910
#  2897/5000: episode: 97, duration: 0.867s, episode steps:  53, steps per second:  61, episode reward: 53.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.528 [0.000, 1.000],  loss: 2.890287, mse: 199.315141, accuracy: 0.565448, mean_q: 20.395831, mean_eps: 0.741700
#  2959/5000: episode: 98, duration: 0.966s, episode steps:  62, steps per second:  64, episode reward: 62.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.516 [0.000, 1.000],  loss: 2.981939, mse: 208.614515, accuracy: 0.566532, mean_q: 20.854282, mean_eps: 0.736525
#  3011/5000: episode: 99, duration: 0.809s, episode steps:  52, steps per second:  64, episode reward: 52.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 2.631222, mse: 218.120354, accuracy: 0.563101, mean_q: 21.263918, mean_eps: 0.731395
#  3103/5000: episode: 100, duration: 1.426s, episode steps:  92, steps per second:  65, episode reward: 92.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.467 [0.000, 1.000],  loss: 2.850267, mse: 228.721194, accuracy: 0.572011, mean_q: 21.698743, mean_eps: 0.724915
#  3149/5000: episode: 101, duration: 0.721s, episode steps:  46, steps per second:  64, episode reward: 46.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 2.703835, mse: 238.265293, accuracy: 0.573370, mean_q: 22.182557, mean_eps: 0.718705
#  3192/5000: episode: 102, duration: 0.668s, episode steps:  43, steps per second:  64, episode reward: 43.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.535 [0.000, 1.000],  loss: 2.978822, mse: 243.536264, accuracy: 0.560320, mean_q: 22.433567, mean_eps: 0.714700
#  3219/5000: episode: 103, duration: 0.457s, episode steps:  27, steps per second:  59, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.481 [0.000, 1.000],  loss: 2.626810, mse: 244.867465, accuracy: 0.607639, mean_q: 22.574259, mean_eps: 0.711550
#  3246/5000: episode: 104, duration: 0.427s, episode steps:  27, steps per second:  63, episode reward: 27.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.481 [0.000, 1.000],  loss: 2.256893, mse: 257.300665, accuracy: 0.564815, mean_q: 23.193346, mean_eps: 0.709120
#  3265/5000: episode: 105, duration: 0.305s, episode steps:  19, steps per second:  62, episode reward: 19.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.474 [0.000, 1.000],  loss: 2.096752, mse: 256.612574, accuracy: 0.597039, mean_q: 23.327980, mean_eps: 0.707050
#  3409/5000: episode: 106, duration: 2.204s, episode steps: 144, steps per second:  65, episode reward: 144.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.507 [0.000, 1.000],  loss: 2.975029, mse: 271.706322, accuracy: 0.566623, mean_q: 23.763514, mean_eps: 0.699715
#  3435/5000: episode: 107, duration: 0.416s, episode steps:  26, steps per second:  62, episode reward: 26.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.538 [0.000, 1.000],  loss: 3.107056, mse: 283.158939, accuracy: 0.592548, mean_q: 24.247168, mean_eps: 0.692065
#  3510/5000: episode: 108, duration: 1.157s, episode steps:  75, steps per second:  65, episode reward: 75.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.493 [0.000, 1.000],  loss: 3.350572, mse: 291.198566, accuracy: 0.577500, mean_q: 24.546488, mean_eps: 0.687520
#  3604/5000: episode: 109, duration: 1.446s, episode steps:  94, steps per second:  65, episode reward: 94.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.489 [0.000, 1.000],  loss: 1.897116, mse: 309.542223, accuracy: 0.574801, mean_q: 25.455303, mean_eps: 0.679915
#  3618/5000: episode: 110, duration: 0.230s, episode steps:  14, steps per second:  61, episode reward: 14.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.643 [0.000, 1.000],  loss: 3.066969, mse: 319.828306, accuracy: 0.600446, mean_q: 25.765152, mean_eps: 0.675055
#  3705/5000: episode: 111, duration: 1.346s, episode steps:  87, steps per second:  65, episode reward: 87.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.517 [0.000, 1.000],  loss: 2.704012, mse: 328.970230, accuracy: 0.588362, mean_q: 26.158506, mean_eps: 0.670510
#  3795/5000: episode: 112, duration: 1.395s, episode steps:  90, steps per second:  65, episode reward: 90.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 2.803348, mse: 342.242399, accuracy: 0.574653, mean_q: 26.712989, mean_eps: 0.662545
#  3909/5000: episode: 113, duration: 1.759s, episode steps: 114, steps per second:  65, episode reward: 114.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.491 [0.000, 1.000],  loss: 2.707711, mse: 366.613565, accuracy: 0.580592, mean_q: 27.560823, mean_eps: 0.653365
#  3958/5000: episode: 114, duration: 0.781s, episode steps:  49, steps per second:  63, episode reward: 49.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.551 [0.000, 1.000],  loss: 2.795889, mse: 375.395158, accuracy: 0.580357, mean_q: 27.902453, mean_eps: 0.646030
#  4060/5000: episode: 115, duration: 1.594s, episode steps: 102, steps per second:  64, episode reward: 102.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.490 [0.000, 1.000],  loss: 2.492258, mse: 395.353666, accuracy: 0.579657, mean_q: 28.676510, mean_eps: 0.639235
#  4099/5000: episode: 116, duration: 0.614s, episode steps:  39, steps per second:  64, episode reward: 39.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.538 [0.000, 1.000],  loss: 4.167336, mse: 409.397054, accuracy: 0.584135, mean_q: 29.268742, mean_eps: 0.632890
#  4161/5000: episode: 117, duration: 0.962s, episode steps:  62, steps per second:  64, episode reward: 62.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.500 [0.000, 1.000],  loss: 2.347661, mse: 421.805257, accuracy: 0.583165, mean_q: 29.682958, mean_eps: 0.628345
#  4307/5000: episode: 118, duration: 2.278s, episode steps: 146, steps per second:  64, episode reward: 146.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.514 [0.000, 1.000],  loss: 3.254374, mse: 447.616397, accuracy: 0.582406, mean_q: 30.465114, mean_eps: 0.618985
#  4341/5000: episode: 119, duration: 0.543s, episode steps:  34, steps per second:  63, episode reward: 34.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.441 [0.000, 1.000],  loss: 2.559913, mse: 470.825798, accuracy: 0.585478, mean_q: 31.360556, mean_eps: 0.610885
#  4439/5000: episode: 120, duration: 1.542s, episode steps:  98, steps per second:  64, episode reward: 98.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.480 [0.000, 1.000],  loss: 1.933175, mse: 498.608888, accuracy: 0.576849, mean_q: 32.347384, mean_eps: 0.604945
#  4558/5000: episode: 121, duration: 1.877s, episode steps: 119, steps per second:  63, episode reward: 119.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.504 [0.000, 1.000],  loss: 2.665553, mse: 519.177926, accuracy: 0.592700, mean_q: 33.072122, mean_eps: 0.595180
#  4677/5000: episode: 122, duration: 1.852s, episode steps: 119, steps per second:  64, episode reward: 119.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.479 [0.000, 1.000],  loss: 3.266588, mse: 553.745936, accuracy: 0.578782, mean_q: 33.982879, mean_eps: 0.584470
#  4840/5000: episode: 123, duration: 2.743s, episode steps: 163, steps per second:  59, episode reward: 163.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.497 [0.000, 1.000],  loss: 2.594510, mse: 602.258487, accuracy: 0.584548, mean_q: 35.471152, mean_eps: 0.571780
#  4997/5000: episode: 124, duration: 2.429s, episode steps: 157, steps per second:  65, episode reward: 157.000, mean reward:  1.000 [ 1.000,  1.000], mean action: 0.503 [0.000, 1.000],  loss: 3.193938, mse: 644.580744, accuracy: 0.586584, mean_q: 36.662555, mean_eps: 0.557380
# done, took 80.529 seconds

# %%
"""
action = 0
observation, reward, done, info = env.step(action)
print("Observations after action: ", observation)
print("Reward for this step: ", reward)
print("Episode Completion: ", done)


"""
# Out:
# '\naction = 0\nobservation, reward, done, info = env.step(action)\nprint("Observations after action: ", observation)\nprint("Reward for this step: ", reward)\nprint("Episode Completion: ", done)\n\n\n'

# %%
# Visualize the history for number of Training episode steps of the Cart Pole Game
plt.figure(figsize = (18,10))
plt.plot(history.history['nb_episode_steps'])
plt.ylabel('nb_episode_steps')
plt.xlabel('episodes')
plt.show()

# %%
# Finally, evaluate and test our algorithm for 100 episodes.
dqn.test(env, nb_episodes=100, visualize=False)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 200.000, steps: 200
# Episode 2: reward: 500.000, steps: 500
# Episode 3: reward: 200.000, steps: 200
# Episode 4: reward: 309.000, steps: 309
# Episode 5: reward: 356.000, steps: 356
# Episode 6: reward: 278.000, steps: 278
# Episode 7: reward: 284.000, steps: 284
# Episode 8: reward: 192.000, steps: 192
# Episode 9: reward: 257.000, steps: 257
# Episode 10: reward: 267.000, steps: 267
# Episode 11: reward: 216.000, steps: 216
# Episode 12: reward: 242.000, steps: 242
# Episode 13: reward: 500.000, steps: 500
# Episode 14: reward: 290.000, steps: 290
# Episode 15: reward: 500.000, steps: 500
# Episode 16: reward: 282.000, steps: 282
# Episode 17: reward: 365.000, steps: 365
# Episode 18: reward: 215.000, steps: 215
# Episode 19: reward: 291.000, steps: 291
# Episode 20: reward: 383.000, steps: 383
# Episode 21: reward: 370.000, steps: 370
# Episode 22: reward: 256.000, steps: 256
# Episode 23: reward: 260.000, steps: 260
# Episode 24: reward: 372.000, steps: 372
# Episode 25: reward: 174.000, steps: 174
# Episode 26: reward: 188.000, steps: 188
# Episode 27: reward: 238.000, steps: 238
# Episode 28: reward: 200.000, steps: 200
# Episode 29: reward: 283.000, steps: 283
# Episode 30: reward: 251.000, steps: 251
# Episode 31: reward: 303.000, steps: 303
# Episode 32: reward: 187.000, steps: 187
# Episode 33: reward: 211.000, steps: 211
# Episode 34: reward: 241.000, steps: 241
# Episode 35: reward: 295.000, steps: 295
# Episode 36: reward: 191.000, steps: 191
# Episode 37: reward: 500.000, steps: 500
# Episode 38: reward: 353.000, steps: 353
# Episode 39: reward: 239.000, steps: 239
# Episode 40: reward: 193.000, steps: 193
# Episode 41: reward: 257.000, steps: 257
# Episode 42: reward: 356.000, steps: 356
# Episode 43: reward: 337.000, steps: 337
# Episode 44: reward: 334.000, steps: 334
# Episode 45: reward: 318.000, steps: 318
# Episode 46: reward: 351.000, steps: 351
# Episode 47: reward: 197.000, steps: 197
# Episode 48: reward: 224.000, steps: 224
# Episode 49: reward: 204.000, steps: 204
# Episode 50: reward: 208.000, steps: 208
# Episode 51: reward: 397.000, steps: 397
# Episode 52: reward: 431.000, steps: 431
# Episode 53: reward: 410.000, steps: 410
# Episode 54: reward: 267.000, steps: 267
# Episode 55: reward: 309.000, steps: 309
# Episode 56: reward: 249.000, steps: 249
# Episode 57: reward: 382.000, steps: 382
# Episode 58: reward: 439.000, steps: 439
# Episode 59: reward: 194.000, steps: 194
# Episode 60: reward: 246.000, steps: 246
# Episode 61: reward: 241.000, steps: 241
# Episode 62: reward: 275.000, steps: 275
# Episode 63: reward: 376.000, steps: 376
# Episode 64: reward: 382.000, steps: 382
# Episode 65: reward: 215.000, steps: 215
# Episode 66: reward: 321.000, steps: 321
# Episode 67: reward: 500.000, steps: 500
# Episode 68: reward: 256.000, steps: 256
# Episode 69: reward: 253.000, steps: 253
# Episode 70: reward: 500.000, steps: 500
# Episode 71: reward: 304.000, steps: 304
# Episode 72: reward: 313.000, steps: 313
# Episode 73: reward: 223.000, steps: 223
# Episode 74: reward: 199.000, steps: 199
# Episode 75: reward: 308.000, steps: 308
# Episode 76: reward: 209.000, steps: 209
# Episode 77: reward: 190.000, steps: 190
# Episode 78: reward: 237.000, steps: 237
# Episode 79: reward: 285.000, steps: 285
# Episode 80: reward: 282.000, steps: 282
# Episode 81: reward: 212.000, steps: 212
# Episode 82: reward: 197.000, steps: 197
# Episode 83: reward: 251.000, steps: 251
# Episode 84: reward: 500.000, steps: 500
# Episode 85: reward: 295.000, steps: 295
# Episode 86: reward: 227.000, steps: 227
# Episode 87: reward: 443.000, steps: 443
# Episode 88: reward: 289.000, steps: 289
# Episode 89: reward: 379.000, steps: 379
# Episode 90: reward: 260.000, steps: 260
# Episode 91: reward: 428.000, steps: 428
# Episode 92: reward: 196.000, steps: 196
# Episode 93: reward: 326.000, steps: 326
# Episode 94: reward: 240.000, steps: 240
# Episode 95: reward: 393.000, steps: 393
# Episode 96: reward: 500.000, steps: 500
# Episode 97: reward: 287.000, steps: 287
# Episode 98: reward: 334.000, steps: 334
# Episode 99: reward: 392.000, steps: 392
# Episode 100: reward: 242.000, steps: 242

# %%
# After training is done, we save the final weights.
dqn.save_weights('dqn_weights.h5f', overwrite=False)
# Out:
# [WARNING] dqn_weights.h5f.index already exists - overwrite? [y/n]y
# [TIP] Next time specify overwrite=True!
# 2023-03-05 12:31:22.914862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-05 12:31:22.914904: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-03-05 12:31:22.942909: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
observation = env.reset()
dqn.load_weights('dqn_weights.h5f')
action = dqn.forward(observation)

print("Observation: ", observation)
print("Chosen action: ", action)

new_observation, reward, done, info = env.step(action)
print("Observations after action: ", new_observation)
print("Reward for this step: ", reward)
print("Episode Completion: ", done)
# Out:
# Observation:  [-0.03596123  0.0128352   0.04575599 -0.02172864]
# Chosen action:  1
# Observations after action:  [-0.03570452  0.20727211  0.04532142 -0.29963119]
# Reward for this step:  1.0
# Episode Completion:  False
# 2023-03-05 12:31:22.982038: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Task 2

# %% [markdown]
# Each Episode comprises of multiple steps. The environment is reset at the start of each episode as required. Next, the Agent makes the forward step based on the observation, before updating the new episode reward and observation for the next step. This continues until the termination criteria or truncation value of 500. Each cumulative reward is stored in a list and mapped out in the graph.

# %%
num_episodes = 100
episode_results = []
dqn.load_weights('dqn_weights.h5f')
for i in range(1,num_episodes+1):
    # Reset environment at the beginning of each episode
    observation = env.reset()
    cumulative_reward = 0
    done = False

    while not done:
        # Agent takes action based on observation
        action = dqn.forward(observation)
        
        # Environment processes action and returns new observation, reward, and done flag
        new_observation, reward, done, info = env.step(action)

        # Update episode reward and observation for next step
        observation = new_observation
        cumulative_reward += reward
        
    print("Episode:", i, " Cumulative reward: ", cumulative_reward)
    episode_results.append(cumulative_reward)
# Out:
# Episode: 1  Cumulative reward:  311.0
# Episode: 2  Cumulative reward:  420.0
# Episode: 3  Cumulative reward:  230.0
# Episode: 4  Cumulative reward:  298.0
# Episode: 5  Cumulative reward:  500.0
# Episode: 6  Cumulative reward:  222.0
# Episode: 7  Cumulative reward:  308.0
# Episode: 8  Cumulative reward:  286.0
# Episode: 9  Cumulative reward:  349.0
# Episode: 10  Cumulative reward:  213.0
# Episode: 11  Cumulative reward:  259.0
# Episode: 12  Cumulative reward:  231.0
# Episode: 13  Cumulative reward:  205.0
# Episode: 14  Cumulative reward:  257.0
# Episode: 15  Cumulative reward:  224.0
# Episode: 16  Cumulative reward:  211.0
# Episode: 17  Cumulative reward:  299.0
# Episode: 18  Cumulative reward:  288.0
# Episode: 19  Cumulative reward:  262.0
# Episode: 20  Cumulative reward:  351.0
# Episode: 21  Cumulative reward:  204.0
# Episode: 22  Cumulative reward:  284.0
# Episode: 23  Cumulative reward:  500.0
# Episode: 24  Cumulative reward:  295.0
# Episode: 25  Cumulative reward:  291.0
# Episode: 26  Cumulative reward:  500.0
# Episode: 27  Cumulative reward:  461.0
# Episode: 28  Cumulative reward:  223.0
# Episode: 29  Cumulative reward:  245.0
# Episode: 30  Cumulative reward:  296.0
# Episode: 31  Cumulative reward:  316.0
# Episode: 32  Cumulative reward:  228.0
# Episode: 33  Cumulative reward:  259.0
# Episode: 34  Cumulative reward:  306.0
# Episode: 35  Cumulative reward:  185.0
# Episode: 36  Cumulative reward:  181.0
# Episode: 37  Cumulative reward:  453.0
# Episode: 38  Cumulative reward:  487.0
# Episode: 39  Cumulative reward:  295.0
# Episode: 40  Cumulative reward:  245.0
# Episode: 41  Cumulative reward:  309.0
# Episode: 42  Cumulative reward:  183.0
# Episode: 43  Cumulative reward:  278.0
# Episode: 44  Cumulative reward:  284.0
# Episode: 45  Cumulative reward:  270.0
# Episode: 46  Cumulative reward:  407.0
# Episode: 47  Cumulative reward:  231.0
# Episode: 48  Cumulative reward:  437.0
# Episode: 49  Cumulative reward:  216.0
# Episode: 50  Cumulative reward:  322.0
# Episode: 51  Cumulative reward:  223.0
# Episode: 52  Cumulative reward:  433.0
# Episode: 53  Cumulative reward:  394.0
# Episode: 54  Cumulative reward:  281.0
# Episode: 55  Cumulative reward:  275.0
# Episode: 56  Cumulative reward:  301.0
# Episode: 57  Cumulative reward:  187.0
# Episode: 58  Cumulative reward:  248.0
# Episode: 59  Cumulative reward:  263.0
# Episode: 60  Cumulative reward:  372.0
# Episode: 61  Cumulative reward:  212.0
# Episode: 62  Cumulative reward:  432.0
# Episode: 63  Cumulative reward:  281.0
# Episode: 64  Cumulative reward:  306.0
# Episode: 65  Cumulative reward:  280.0
# Episode: 66  Cumulative reward:  283.0
# Episode: 67  Cumulative reward:  300.0
# Episode: 68  Cumulative reward:  293.0
# Episode: 69  Cumulative reward:  395.0
# Episode: 70  Cumulative reward:  307.0
# Episode: 71  Cumulative reward:  259.0
# Episode: 72  Cumulative reward:  269.0
# Episode: 73  Cumulative reward:  500.0
# Episode: 74  Cumulative reward:  283.0
# Episode: 75  Cumulative reward:  222.0
# Episode: 76  Cumulative reward:  334.0
# Episode: 77  Cumulative reward:  195.0
# Episode: 78  Cumulative reward:  289.0
# Episode: 79  Cumulative reward:  278.0
# Episode: 80  Cumulative reward:  241.0
# Episode: 81  Cumulative reward:  419.0
# Episode: 82  Cumulative reward:  224.0
# Episode: 83  Cumulative reward:  290.0
# Episode: 84  Cumulative reward:  239.0
# Episode: 85  Cumulative reward:  438.0
# Episode: 86  Cumulative reward:  279.0
# Episode: 87  Cumulative reward:  232.0
# Episode: 88  Cumulative reward:  409.0
# Episode: 89  Cumulative reward:  285.0
# Episode: 90  Cumulative reward:  293.0
# Episode: 91  Cumulative reward:  366.0
# Episode: 92  Cumulative reward:  334.0
# Episode: 93  Cumulative reward:  473.0
# Episode: 94  Cumulative reward:  177.0
# Episode: 95  Cumulative reward:  323.0
# Episode: 96  Cumulative reward:  203.0
# Episode: 97  Cumulative reward:  223.0
# Episode: 98  Cumulative reward:  251.0
# Episode: 99  Cumulative reward:  189.0
# Episode: 100  Cumulative reward:  210.0

# %%
plt.plot(episode_results)
plt.title('Cumulative reward for each episode')
plt.ylabel('Cumulative reward')
plt.xlabel('episode')
plt.show()

# %%
mean = sum(episode_results) / len(episode_results)
print("Average cumulative reward:", mean)
print("Is my agent good enough?", mean > 195)
# Out:
# Average cumulative reward: 297.08
# Is my agent good enough? True

# %% [markdown]
# ## Task 3
